# %% [markdown]
# <a href="https://colab.research.google.com/github/JARIN-TIAS/NLP/blob/main/twitter_sentiment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import spacy
df=pd.read_csv('/content/twitter_training.csv')
df.head()
# Out:
#    2401  Borderlands  Positive  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#   im getting on borderlands and i will murder you all ,
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
#droping unnecessary column
df.drop(columns=['2401'], inplace=True)
df.head()
# Out:
#    Borderlands  Positive im getting on borderlands and i will murder you all ,
# 0  Borderlands  Positive  I am coming to the borders and I will kill you...
# 1  Borderlands  Positive  im getting on borderlands and i will kill you ...
# 2  Borderlands  Positive  im coming on borderlands and i will murder you...
# 3  Borderlands  Positive  im getting on borderlands 2 and i will murder ...
# 4  Borderlands  Positive  im getting into borderlands and i can murder y...

# %%
df.columns
# Out:
# Index(['Borderlands', 'Positive',
#        'im getting on borderlands and i will murder you all ,'],
#       dtype='object')

# %%
#rename column
df.rename(columns={'Borderlands': 'Game_Name',
              'im getting on borderlands and i will murder you all ,': 'Tweet',
                'Positive':'Sentiment'}, inplace= True)
df.head()
# Out:
#      Game_Name Sentiment                                              Tweet
# 0  Borderlands  Positive  I am coming to the borders and I will kill you...
# 1  Borderlands  Positive  im getting on borderlands and i will kill you ...
# 2  Borderlands  Positive  im coming on borderlands and i will murder you...
# 3  Borderlands  Positive  im getting on borderlands 2 and i will murder ...
# 4  Borderlands  Positive  im getting into borderlands and i can murder y...

# %% [markdown]
# #handling missing values

# %%
df.isnull().sum()
# Out:
# Game_Name      0
# Sentiment      0
# Tweet        686
# dtype: int64

# %%
df.shape
# Out:
# (74681, 3)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Game_Name    0
# Sentiment    0
# Tweet        0
# dtype: int64

# %%
df.shape
# Out:
# (73995, 3)

# %% [markdown]
# # ***creating new data base reducing to 2000 counts for each sentiments***

# %%
df.Sentiment.value_counts()
# Out:
# Sentiment
# Negative      22358
# Positive      20654
# Neutral       18108
# Irrelevant    12875
# Name: count, dtype: int64

# %%
# Select the first 2000 rows for each sentiment category
df_positive = df[df['Sentiment'] == 'Positive'].iloc[:2000]
df_negative = df[df['Sentiment'] == 'Negative'].iloc[:2000]
df_neutral = df[df['Sentiment'] == 'Neutral'].iloc[:2000]
df_irrelevant = df[df['Sentiment'] == 'Irrelevant'].iloc[:2000]

# %%
df2=pd.concat([df_positive, df_negative, df_neutral, df_irrelevant])
df2.shape
# Out:
# (8000, 3)

# %%
df2.Sentiment.value_counts()
# Out:
# Sentiment
# Positive      2000
# Negative      2000
# Neutral       2000
# Irrelevant    2000
# Name: count, dtype: int64

# %%
df2.head()
# Out:
#      Game_Name Sentiment                                              Tweet
# 0  Borderlands  Positive  I am coming to the borders and I will kill you...
# 1  Borderlands  Positive  im getting on borderlands and i will kill you ...
# 2  Borderlands  Positive  im coming on borderlands and i will murder you...
# 3  Borderlands  Positive  im getting on borderlands 2 and i will murder ...
# 4  Borderlands  Positive  im getting into borderlands and i can murder y...

# %% [markdown]
# # ***categorical to numeric***
